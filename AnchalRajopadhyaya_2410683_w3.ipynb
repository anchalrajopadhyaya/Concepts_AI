# %% [markdown]
# ***TO-DO Task***

# %% [markdown]
# 3.1

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Concepts and technology of AI/Titanic-Dataset.csv")

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#1
fare = df['Fare']
print("DataFrame with Fare column only: ")
print(fare.head())
# Out:
# DataFrame with Fare column only:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
#2
class_age = df[['Age', 'Pclass']]
print("DataFrame containing Pclass and Fare column: ")
print(class_age.head())
# Out:
# DataFrame containing Pclass and Fare column:
#     Age  Pclass
# 0  22.0       3
# 1  38.0       1
# 2  26.0       3
# 3  35.0       1
# 4  35.0       3

# %%
#3
survived_gander = df[['Survived', 'Sex']]
print("DataFrame containing Survived and Sex column: ")
print(survived_gander.head())
# Out:
# DataFrame containing Survived and Sex column:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
#2.1
#1
fare_gt_100 = df[df['Fare'] > 100]
print("Filtered dataset with fare > 100")
print(fare_gt_100.head())
# Out:
# Filtered dataset with fare > 100
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.0      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                            Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# 88       2     19950  263.0000  C23 C25 C27        S
# 118      1  PC 17558  247.5208      B58 B60        C
# ...

# %%
#2
first_class = df[df['Pclass'] == 1]
print("Filtered dataset with Pclass = 1")
print(first_class.head())
# Out:
# Filtered dataset with Pclass = 1
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S

# %%
#3
female_under_18 = df[(df['Age'] < 18) & (df['Sex'] == 'Female')]
print("Filtered dataset with Age < 18 and Sex = Female")
print(female_under_18.head())
# Out:
# Filtered dataset with Age < 18 and Sex = Female
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#2.2
#1
embarked_c_or_s = df[df['Embarked'].isin(['C', 'S'])]
print("Filtered dataset with Embarked = C or Embarked = S: ")
print(embarked_c_or_s.head())
# Out:
# Filtered dataset with Embarked = C or Embarked = S:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
#2
first_second_class = df[df['Pclass'].isin(['1', '2'])]
print("Filtered dataset with Pclass = 1 or Pclass = 2: ")
print(first_second_class.head())
# Out:
# Filtered dataset with Pclass = 1 or Pclass = 2:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#3.2
median_age = df['Age'].median()

df["Age"] = df["Age"].fillna(median_age)

df["Age"] = df["Age"] / 2

print("Updated DataFrame by filling Age column with the median age")
print(df)
# Out:
# Updated DataFrame by filling Age column with the median age
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  11.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19.0      1
# 2                               Heikkinen, Miss. Laina  female  13.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  17.5      1
# 4                             Allen, Mr. William Henry    male  17.5      0
# ...

# %%
#1
df['Fare per year'] = df['Fare'] / df['Age']
print("Updated DataFrame with new column 'Fare per year': ")
df
# Out:
# Updated DataFrame with new column 'Fare per year':
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  11.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19.0      1
# 2                               Heikkinen, Miss. Laina  female  13.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  17.5      1
# 4                             Allen, Mr. William Henry    male  17.5      0
# ...

# %%
#2
high_fare_age = df.loc[df['Fare per year'] > 5]
print("\nSubset with fare-per-year higher than 5: \n", high_fare_age)

#3
high_fare_age_srt = df.sort_values(by = 'Fare per year', ascending=False)
print("\nSorting high-fare-age by descending fare-per-year: \n", high_fare_age_srt)
# Out:
# Subset with fare-per-year higher than 5:
#       PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 27            28         0       1
# ..           ...       ...     ...
# 831          832         1       2
# 849          850         1       1
# 850          851         0       3
# 856          857         1       1
# 869          870         1       3
#
#                                              Name     Sex     Age  SibSp  \
# 7                  Palsson, Master. Gosta Leonard    male   1.000      3
# 10                Sandstrom, Miss. Marguerite Rut  female   2.000      1
# 16                           Rice, Master. Eugene    male   1.000      4
# 24                  Palsson, Miss. Torborg Danira  female   4.000      3
# 27                 Fortune, Mr. Charles Alexander    male   9.500      3
# ...

# %%
#4
result = df[['Name','Fare per year']]
print("Name and fare_per_year columns of high_fare_age_srt: \n", result)

#5
result.head()
# Out:
# Name and fare_per_year columns of high_fare_age_srt:
#                                                    Name  Fare per year
# 0                              Braund, Mr. Owen Harris       0.659091
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       3.751753
# 2                               Heikkinen, Miss. Laina       0.609615
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       3.034286
# 4                             Allen, Mr. William Henry       0.460000
# ..                                                 ...            ...
# 886                              Montvila, Rev. Juozas       0.962963
# 887                       Graham, Miss. Margaret Edith       3.157895
# 888           Johnston, Miss. Catherine Helen "Carrie"       1.675000
# 889                              Behr, Mr. Karl Howell       2.307692
# 890                                Dooley, Mr. Patrick       0.484375
#
# [891 rows x 2 columns]
# ...

# %%
#1
df['Fare per class'] = df['Fare'] / df['Pclass']
print("Updated DataFrame with new column 'Fare per year': ")
df
# Out:
# Updated DataFrame with new column 'Fare per year':
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  11.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19.0      1
# 2                               Heikkinen, Miss. Laina  female  13.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  17.5      1
# 4                             Allen, Mr. William Henry    male  17.5      0
# ...

# %%
#2
adult_males = df.loc[(df['Sex'] == 'Male') & (df['Age'] >= 18)]
print("\nSubset using loc: \n", adult_males)

#3
adult_males_srt = df.sort_values(by = 'Fare per class', ascending=False)
print("\nSorting adult males by descending fare per class: \n", adult_males_srt)
# Out:
# Subset using loc:
#  Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Fare per year, Fare per class]
# Index: []
#
# Sorting adult males by descending fare per class:
#       PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 271          272         1       3        Tornquist, Mr. William Henry
# 263          264         0       1               Harrison, Mr. William
# 597          598         0       3                 Johnson, Mr. Alfred
# ...

# %%
#4
result = df[['Name', 'Age', 'Fare per year']]
print("\nSelected Name, Age and fare_per_year columns: \n", result)
# Out:
# Selected Name, Age and fare_per_year columns:
#                                                    Name   Age  Fare per year
# 0                              Braund, Mr. Owen Harris  11.0       0.659091
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  19.0       3.751753
# 2                               Heikkinen, Miss. Laina  13.0       0.609615
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  17.5       3.034286
# 4                             Allen, Mr. William Henry  17.5       0.460000
# ..                                                 ...   ...            ...
# 886                              Montvila, Rev. Juozas  13.5       0.962963
# 887                       Graham, Miss. Margaret Edith   9.5       3.157895
# 888           Johnston, Miss. Catherine Helen "Carrie"  14.0       1.675000
# 889                              Behr, Mr. Karl Howell  13.0       2.307692
# 890                                Dooley, Mr. Patrick  16.0       0.484375
#
# ...

# %%
#3.3

#1
total_fare = df['Fare'].sum()
print("Total Fare: ", total_fare)

#2
first_class_fare = df.loc[df['Pclass'] == 1, 'Fare'].sum()
print("Total Fare for passengers in first class: ", first_class_fare)

#3
second_class_fare = df.loc[df['Pclass'] == 2, 'Fare'].sum()
print("Total Fare for passengers in second class: ", second_class_fare)

third_class_fare = df.loc[df['Pclass'] == 3, 'Fare'].sum()
print("Total Fare for passengers in third class: \n", third_class_fare)

second_third_class_fare = df.loc[df['Pclass'].isin([2, 3]), 'Fare'].sum()
print("Total Fare for passengers in second and third class: ", second_third_class_fare)
# Out:
# Total Fare:  28693.9493
# Total Fare for passengers in first class:  18177.4125
# Total Fare for passengers in second class:  3801.8417
# Total Fare for passengers in third class:
#  6714.6951
# Total Fare for passengers in second and third class:  10516.536799999998

# %%
#4
fare_totals = [total_fare, first_class_fare, second_class_fare, third_class_fare]
print("List of fare totals: ", fare_totals)
# Out:
# List of fare totals:  [28693.9493, 18177.4125, 3801.8417, 6714.6951]

# %%
first_proportion = first_class_fare / total_fare
second_proportion = second_class_fare / total_fare
third_proportion = third_class_fare / total_fare

print("--Proportion of fare revenue by class--")
print("First class: ",first_proportion)
print("Second class: ",second_proportion)
print("Third class: ",third_proportion)
# Out:
# --Proportion of fare revenue by class--
# First class:  0.6334928771899656
# Second class:  0.1324962855496507
# Third class:  0.23401083726038366

# %%
print("Percentage proportion of total fare from each passenger class")

first_class_proportion_percent  = first_proportion * 100
print("First class proportion: ", first_class_proportion_percent, "%")

second_class_proportion_percent  = second_proportion * 100
print("Second class proportion: ", second_class_proportion_percent, "%")

third_class_proportion_percent  = third_proportion * 100
print("Third class proportion: ", third_class_proportion_percent, "%")
# Out:
# Percentage proportion of total fare from each passenger class
# First class proportion:  63.349287718996564 %
# Second class proportion:  13.24962855496507 %
# Third class proportion:  23.401083726038365 %

# %%
#1
def categorize_age(age):
    if age < 18:
        return "Child"
    elif age < 65:
        return "Adult"
    else:
        return "Senior"

df["Age Group"] = df["Age"].apply(categorize_age)

print(df[["Age", "Age Group"]])
# Out:
#       Age Age Group
# 0    11.0     Child
# 1    19.0     Adult
# 2    13.0     Child
# 3    17.5     Child
# 4    17.5     Child
# ..    ...       ...
# 886  13.5     Child
# 887   9.5     Child
# 888  14.0     Child
# 889  13.0     Child
# 890  16.0     Child
#
# [891 rows x 2 columns]

# %%
#2
total_passengers = len(df)
print("Total number of passengers: ", total_passengers)

#3
age_group_counts = {
    "Child": (df["Age Group"] == "Child").sum(),
    "Adult": (df["Age Group"] == "Adult").sum(),
    "Senior": (df["Age Group"] == "Senior").sum(),
}

print("Number of passengers in each age group: \n", age_group_counts)
# Out:
# Total number of passengers:  891
# Number of passengers in each age group:
#  {'Child': 674, 'Adult': 217, 'Senior': 0}

# %%
#4
child_count_proportion = age_group_counts['Child'] / total_passengers
print("Child Proportion: ",child_count_proportion)

adult_count_proportion = age_group_counts['Adult'] / total_passengers
print("Adult Proportion: ", adult_count_proportion)

senior_count_proportion = age_group_counts['Senior'] / total_passengers
print("Senior Proportion: ", senior_count_proportion)
# Out:
# Child Proportion:  0.7564534231200898
# Adult Proportion:  0.24354657687991021
# Senior Proportion:  0.0

# %%
#5
child_count_proportion_percent = child_count_proportion * 100
print("Child Proportion: ",child_count_proportion_percent,"%")

adult_count_proportion_percent = adult_count_proportion * 100
print("Adult Proportion: ", adult_count_proportion_percent,"%")

senior_count_proportion_percent = senior_count_proportion * 100
print("Senior Proportion: ", senior_count_proportion_percent,"%")
# Out:
# Child Proportion:  75.64534231200898 %
# Adult Proportion:  24.354657687991022 %
# Senior Proportion:  0.0 %

# %% [markdown]
# Class

# %%
start = 1
end = 1000
divisor = 12

divisible_by_12 = [num for num in range(start, end + 1) if num % divisor == 0]

total_numbers = end - start + 1  # Total numbers in the range
count_divisible_by_12 = len(divisible_by_12)
probability = count_divisible_by_12 / total_numbers

# Print results
print("Numbers divisible by 12:", divisible_by_12)
print("Count of numbers divisible by 12:", count_divisible_by_12)
print("Probability P(A12):", probability)
# Out:
# Numbers divisible by 12: [12, 24, 36, 48, 60, 72, 84, 96, 108, 120, 132, 144, 156, 168, 180, 192, 204, 216, 228, 240, 252, 264, 276, 288, 300, 312, 324, 336, 348, 360, 372, 384, 396, 408, 420, 432, 444, 456, 468, 480, 492, 504, 516, 528, 540, 552, 564, 576, 588, 600, 612, 624, 636, 648, 660, 672, 684, 696, 708, 720, 732, 744, 756, 768, 780, 792, 804, 816, 828, 840, 852, 864, 876, 888, 900, 912, 924, 936, 948, 960, 972, 984, 996]
# Count of numbers divisible by 12: 83
# Probability P(A12): 0.083

# %%
import pandas as pd

# %%
data = {
    'Name' : ['Alice', 'Bob', 'Charlie', 'David'],
    'Age' : [25, 30, 35, 23],
    'Score' : [88,89,90,56]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     89
# 2  Charlie   35     90
# 3    David   23     56

# %%
df_sortAge = df.sort_values(by='Age')
df_sortAge.head()
# Out:
#       Name  Age  Score
# 3    David   23     56
# 0    Alice   25     88
# 1      Bob   30     89
# 2  Charlie   35     90

# %%
df_sortScore = df.sort_index()
df_sortScore.head()
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     89
# 2  Charlie   35     90
# 3    David   23     56

# %%
subset_iloc = df.iloc[1:4, 0:2]
print("Subset using iloc")
print(subset_iloc)
# Out:
# Subset using iloc
#       Name  Age
# 1      Bob   30
# 2  Charlie   35
# 3    David   23

# %%
first_two_rows = df.iloc[1:2]
print("first two rows:\n",first_two_rows)
# Out:
# first two rows:
#    Name  Age  Score
# 1  Bob   30     89

# %%
subset_loc = df.loc[df['Age']>25, ['Name', 'Score', 'Age']]
print("Subset using loc")
print(subset_loc)
# Out:
# Subset using loc
#       Name  Score  Age
# 1      Bob     89   30
# 2  Charlie     90   35

# %%
subset_bracket = df[[ 'Age']]
print("Subset using bracket")
print(subset_bracket)
# Out:
# Subset using bracket
#    Age
# 0   25
# 1   30
# 2   35
# 3   23

# %%
filtered_multiple = df[(df['Age']>25) & (df['Score']>88)]
print("Filtered using multiple conditions")
print(filtered_multiple)
# Out:
# Filtered using multiple conditions
#       Name  Age  Score
# 1      Bob   30     89
# 2  Charlie   35     90

# %% [markdown]
# Filter By Category

# %%
data = {
    'Name' : ['Alice', 'Bob', 'Charlie', 'David'],
    'Department' : ['HR', 'IT', 'Finance', 'HR'],
    'Score' : [88,89,90,56]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name Department  Score
# 0    Alice         HR     88
# 1      Bob         IT     89
# 2  Charlie    Finance     90
# 3    David         HR     56

# %%
filtered_single = df[df["Department"] == "HR"]
print("Filtered using single condition")
print(filtered_single)
# Out:
# Filtered using single condition
#     Name Department  Score
# 0  Alice         HR     88
# 3  David         HR     56

# %%
filtered_multiple = df [ df ["Department"]. isin ([ "HR", "IT"]) ]
print ( filtered_multiple )
# Out:
#     Name Department  Score
# 0  Alice         HR     88
# 1    Bob         IT     89
# 3  David         HR     56

# %%
data ={
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)

grouped = df.groupby('Category')['Value'].mean()
print(grouped)
# Out:
# Category
# A    30.0
# B    30.0
# Name: Value, dtype: float64

# %%
df['Normalized'] = df.groupby('Category')['Value'].transform(lambda x: x / x.sum())

print(df)
# Out:
#   Category  Value  Normalized
# 0        A     10    0.111111
# 1        B     20    0.333333
# 2        A     30    0.333333
# 3        B     40    0.666667
# 4        A     50    0.555556

# %%
filtered = df.groupby('Category').filter(lambda x: x['Value'].sum() <= 60)
print(filtered)
# Out:
#   Category  Value  Normalized
# 1        B     20    0.333333
# 3        B     40    0.666667

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#time series data ma line plot use garxam
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr'],
    'Sales': [200, 220, 250,280]
}
df = pd.DataFrame(data)
#line plot
df.plot(x='Month', y = 'Sales', kind = 'line', marker = 'o', title = 'Monthly Sales')

plt.show()

# %%
#categorical data bar or pie chart
#continuous data lai histogram ma plot garinxa
#univariate
data = {
    'Scores' : [50,60,70,80,85,90,95,100]
}
df = pd.DataFrame(data)
df['Scores'].plot(kind = 'hist', bins = 5, title = 'Score Distribution', edgecolor = '#FFE5B4')
plt.xlabel('Score')
plt.show()

# %%
data = {
    'Height': [150, 160, 170, 180, 190],
    'Weight': [50, 60, 70, 80, 90]
}
df = pd.DataFrame(data)
df.plot(x='Height', y='Weight', kind='scatter', title='Height vs Weight')
plt.show()

# %%
data = {'Scores': [50,60,70,80,85,90,95,100]}
df = pd.DataFrame(data)
df.boxplot(column = 'Scores')
plt.title('Box Plot of Scores')
plt.show()
